# %% [markdown]
# # GPU in colab
# First, you'll need to enable GPUs for the notebook:
# *   Navigate to Edit→Notebook Settings
# *   select GPU from the Hardware Accelerator drop-down

# %%
# %tensorflow_version 2.x

# %%
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0
# 2022-05-11 18:16:06.996272: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-05-11 18:16:07.059423: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-11 18:16:07.107211: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-11 18:16:07.107371: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-11 18:16:07.656732: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-11 18:16:07.656857: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-11 18:16:07.656933: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-11 18:16:07.657298: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /device:GPU:0 with 5393 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3070 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime

# %%
from google.colab import drive, files

# %%
from keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# # Exercise 1
#
# a) Load and preprocess CIFAR10 Dataset.

# %% [markdown]
# b) Set up the LeNet5 Model with the following modifications
# - Increase the number of filters by a factor of 4
# - Make the kernel size (3, 3)
# - Use ReLu activation function,
# - Add Dropout Layer
# - Replace  AveragePooling with MaxPooling replacing

# %% [markdown]
# c) Set up the callbacks

# %% [markdown]
# ## Optimizer & Compling the model

# %% [markdown]
# d) Compile the model and fit the data to the model

# %% [markdown]
# e) Plot the accuracy and loss curves, also view it on tensorboard.

# %% [markdown]
# f)  Load the best saved model

# %% [markdown]
# g) Evaluate the model on the test data and compare your scores with the GUIDE notebook.

# %% [markdown]
# # Exercise 2

# %% [markdown]
# 1. From https://keras.io/api/applications/ use the model of MobileNet and MobileNetV2.
# 2. Set it up for transer-learning (all layers of this network should be frozen) for the cifar10 dataset.
# 3. Fit the network, save the weights and evaluate the model on the test data.
